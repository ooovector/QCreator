# %%
# center12 = (eqd.sample.chip_geometry.sample_horizontal_size/2 - tunable_coupler_length,
#             eqd.sample.chip_geometry.sample_vertical_size/2-qubit_position_offset)

# center34 = (eqd.sample.chip_geometry.sample_horizontal_size/2 - tunable_coupler_length,
#             eqd.sample.chip_geometry.sample_vertical_size/2+qubit_position_offset)

# center56 = (eqd.sample.chip_geometry.sample_horizontal_size/2 + tunable_coupler_length,
#             eqd.sample.chip_geometry.sample_vertical_size/2-qubit_position_offset)

# center78 = (eqd.sample.chip_geometry.sample_horizontal_size/2 + tunable_coupler_length,
#             eqd.sample.chip_geometry.sample_vertical_size/2+qubit_position_offset)

# center41 = (eqd.sample.chip_geometry.sample_horizontal_size/2 - 3/ 2 * tunable_coupler_length,
#             eqd.sample.chip_geometry.sample_vertical_size/2 - side_squid_offset)

# center23 = (eqd.sample.chip_geometry.sample_horizontal_size/2 - tunable_coupler_length / 2,
#             eqd.sample.chip_geometry.sample_vertical_size/2 + side_squid_offset)

# center76 = (eqd.sample.chip_geometry.sample_horizontal_size/2 + 3/ 2 * tunable_coupler_length,
#             eqd.sample.chip_geometry.sample_vertical_size/2 - side_squid_offset)

# center85 = (eqd.sample.chip_geometry.sample_horizontal_size/2 + tunable_coupler_length / 2,
#             eqd.sample.chip_geometry.sample_vertical_size/2 + side_squid_offset)

# %%
# squid_line12 = GFluxControllableSquid(name='squid_inline12', position=center12, w=8, s=coupler_s, g=30,
#                                       layer_configuration=eqd.sample.layer_configuration, squid_params=squid_coupler_horizontal,
#                                       flux_w=flux_w, flux_s=flux_s, flux_g=flux_g)

# squid_line34 = GFluxControllableSquid(name='squid_inline34', position=center34, w=8, s=coupler_s, g=30, invert_y=True,
#                                       layer_configuration=eqd.sample.layer_configuration, squid_params=squid_coupler_horizontal,
#                                       flux_w=flux_w, flux_s=flux_s, flux_g=flux_g)

# squid_line56 = GFluxControllableSquid(name='squid_inline56', position=center56, w=8, s=coupler_s, g=30,
#                                       layer_configuration=eqd.sample.layer_configuration, squid_params=squid_coupler_horizontal,
#                                       flux_w=flux_w, flux_s=flux_s, flux_g=flux_g)
# squid_line78 = GFluxControllableSquid(name='squid_inline78', position=center78, w=8, s=coupler_s, g=30,invert_y=True,
#                                       layer_configuration=eqd.sample.layer_configuration, squid_params=squid_coupler_horizontal,
#                                       flux_w=flux_w, flux_s=flux_s, flux_g=flux_g)
# squid_line41 = GFluxControllableSquid(name='squid_inline41', position = center41, w = 8, s = coupler_s, g= 30, invert_x=True,
#                            layer_configuration = eqd.sample.layer_configuration, squid_params = squid_coupler_vertical,
#                            flux_w = flux_w, flux_s = flux_s, flux_g=flux_g)
# squid_line23 = GFluxControllableSquid(name='squid_inline23', position = center23, w = 8, s = coupler_s, g= 30,
#                            layer_configuration = eqd.sample.layer_configuration, squid_params = squid_coupler_vertical,
#                            flux_w = flux_w, flux_s = flux_s, flux_g=flux_g)
# squid_line76 = GFluxControllableSquid(name='squid_inline76', position = center76, w = 8, s = coupler_s, g= 30,
#                            layer_configuration = eqd.sample.layer_configuration, squid_params = squid_coupler_vertical,
#                            flux_w = flux_w, flux_s = flux_s, flux_g=flux_g)
# squid_line85 = GFluxControllableSquid(name='squid_inline85', position = center85, w = 8, s = coupler_s, g= 30, invert_x=True,
#                            layer_configuration = eqd.sample.layer_configuration, squid_params = squid_coupler_vertical,
#                            flux_w = flux_w, flux_s = flux_s, flux_g=flux_g)

# %%
# # coupler_bridge_spacing = 200
# coupler_bridge_spacing = 500

# #Coupler 12
# eqd.sample.connect_cpw(eqd.coaxmon1, squid_line12, 'coupler3', 'port1', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)
# eqd.sample.connect_cpw(eqd.coaxmon2, squid_line12, 'coupler3', 'port2', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)
# #Coupler 23
# eqd.sample.connect_cpw(eqd.coaxmon2, squid_line23, 'coupler2', 'port1', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)
# eqd.sample.connect_cpw(eqd.coaxmon3, squid_line23, 'coupler2', 'port2', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)
# #Coupler 34
# eqd.sample.connect_cpw(eqd.coaxmon3, squid_line34, 'coupler3', 'port2', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)
# eqd.sample.connect_cpw(eqd.coaxmon4, squid_line34, 'coupler3', 'port1', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)

# #Coupler 56
# eqd.sample.connect_cpw(eqd.coaxmon5, squid_line56, 'coupler3', 'port1', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)
# eqd.sample.connect_cpw(eqd.coaxmon6, squid_line56, 'coupler3', 'port2', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)
# #Coupler 78
# eqd.sample.connect_cpw(eqd.coaxmon7, squid_line78, 'coupler3', 'port2', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)
# eqd.sample.connect_cpw(eqd.coaxmon8, squid_line78, 'coupler3', 'port1', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)
# #Coupler 85
# eqd.sample.connect_cpw(eqd.coaxmon8, squid_line85, 'coupler2', 'port2', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)
# eqd.sample.connect_cpw(eqd.coaxmon5, squid_line85, 'coupler2', 'port1', 'jj-squid cpw', [], airbridge=airbridge,
#                        min_spacing=coupler_bridge_spacing)


# eqd.sample.draw_design()

# %%
Couplers_qubit_left_down = [
    elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift, arc_finish=-3 / 6 + 1 / 100 + shift, phi=-1 / 2,
                                    coupler_type=None, w=10, g=10),
    elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift, arc_finish=3 / 6 - 1 / 100 + shift,
                                    phi=phi1 + 1 / 12,
                                    coupler_type='coupler', w=10, g=10, s=6),  # for resonator
    elements.coaxmon.CoaxmonCoupler(arc_start=3 / 6 + 2 / 100 + shift, arc_finish=5 / 6 - 13 / 100 + shift, phi=1 / 2,
                                    coupler_type='coupler', w=8, g=30, s=26),  # one upper
    elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 11 / 100 + shift, arc_finish=1 / 6 - 4 / 100 + shift, phi=0,
                                    coupler_type='coupler', w=8, g=30, s=26),
    elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 1 / 100 + 1 + shift, arc_finish=1 / 6 - 1 / 100 + 1 + shift,
                                    phi=1,
                                    coupler_type=None, w=10, g=10),
    elements.coaxmon.CoaxmonCoupler(arc_start=-5 / 6 + 1 / 100 + shift, arc_finish=-3 / 6 - 1 / 100 + shift, phi=1,
                                    coupler_type='grounded', w=10, s=6, g=20)
]

Couplers_qubit_left_down_double = [
    elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift, arc_finish=-3 / 6 + 1 / 100 + shift, phi=-1 / 2,
                                    coupler_type=None, w=10, g=10),
    elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift, arc_finish=3 / 6 - 1 / 100 + shift,
                                    phi=phi1 + 1 / 12,
                                    coupler_type='coupler', w=10, g=10, s=6),  # for resonator
    elements.coaxmon.CoaxmonCoupler(arc_start=3 / 6 + 2 / 100 + shift, arc_finish=5 / 6 - 13 / 100 + shift, phi=1 / 2,
                                    coupler_type='coupler', w=8, g=30, s=26),  # one upper
    elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 11 / 100 + shift, arc_finish=1 / 6 - 4 / 100 + shift, phi=0,
                                    coupler_type='coupler', w=8, g=30, s=26),
    elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 1 / 100 + 1 + shift, arc_finish=1 / 6 - 1 / 100 + 1 + shift,
                                    phi=1,
                                    coupler_type='coupler', w=10, s=6, g=20),
    elements.coaxmon.CoaxmonCoupler(arc_start=-5 / 6 + 1 / 100 + shift, arc_finish=-3 / 6 - 1 / 100 + shift, phi=1,
                                    coupler_type='grounded', w=10, s=6, g=20)

]

# Couplers_qubit_left_down_double_coupling = [
#     elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift, arc_finish=-3 / 6 + 1 / 100 + shift, phi=-1 / 2,
#                                     coupler_type=None, w=10, g=10),
#     elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift, arc_finish=3 / 6 - 1 / 100 + shift,
#                                     phi=phi1 + 1 / 12,
#                                     coupler_type='coupler', w=10, g=10, s=6),  # for resonator
#     elements.coaxmon.CoaxmonCoupler(arc_start=3 / 6 + 2 / 100 + shift, arc_finish=5 / 6 - 13 / 100 + shift, phi=1 / 2,
#                                     coupler_type='coupler', w=8, g=30, s=26),  # one upper
#     elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 11 / 100 + shift, arc_finish=1 / 6 - 4 / 100 + shift, phi=0,
#                                     coupler_type='coupler', w=8, g=30, s=26),
#     elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 1 / 100 + 1 + shift, arc_finish=1 / 6 - 1 / 100 + 1 + shift,
#                                     phi=1,
#                                     coupler_type='coupler', w=8, g=30, s=26),
#     elements.coaxmon.CoaxmonCoupler(arc_start=-5 / 6 + 1 / 100 + shift, arc_finish=-3 / 6 - 1 / 100 + shift, phi=1,
#                                     coupler_type='grounded', w=10, s=6, g=20)
# ]
#
Couplers_qubit_right = [elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift + 1 / 6,
                                                        arc_finish=-3 / 6 + 1 / 100 + shift + 1 / 6, phi=-1 / 2,
                                                        coupler_type='grounded', w=10, s=6, g=20),
                        elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift,
                                                        arc_finish=3 / 6 - 1 / 100 + shift, phi=phi1,
                                                        coupler_type='coupler', w=10, g=10, s=6),  # for resonator
                        elements.coaxmon.CoaxmonCoupler(arc_start=3 / 6 + 2 / 100 + shift,
                                                        arc_finish=5 / 6 - 13 / 100 + shift, phi=1 / 2,
                                                        coupler_type='coupler', w=8, g=30, s=26),  # one upper
                        elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 11 / 100 + 1 + shift,
                                                        arc_finish=1 / 6 - 4 / 100 + 1 + shift, phi=1,
                                                        coupler_type='coupler', w=8, g=30, s=26),
                        elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 1 / 100 + shift + 1 / 6,
                                                        arc_finish=1 / 6 - 1 / 100 + shift, phi=0,
                                                        coupler_type=None, w=10, g=40),
                        elements.coaxmon.CoaxmonCoupler(arc_start=-5 / 6 + 1 / 100 + shift,
                                                        arc_finish=-3 / 6 - 1 / 100 + shift + 1 / 6, phi=-1 / 2 - 1 / 3,
                                                        coupler_type=None, w=10, g=40)
                        ]

Couplers_qubit_right_double = [elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift + 1 / 6,
                                                               arc_finish=-3 / 6 + 1 / 100 + shift + 1 / 6, phi=-1 / 2,
                                                               coupler_type='grounded', w=10, s=6, g=20),
                               elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift,
                                                               arc_finish=3 / 6 - 1 / 100 + shift, phi=phi1,
                                                               coupler_type='coupler', w=10, g=10, s=6),
                               # for resonator
                               elements.coaxmon.CoaxmonCoupler(arc_start=3 / 6 + 2 / 100 + shift,
                                                               arc_finish=5 / 6 - 13 / 100 + shift, phi=1 / 2,
                                                               coupler_type='coupler', w=8, g=30, s=26),  # one upper
                               elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 11 / 100 + 1 + shift,
                                                               arc_finish=1 / 6 - 4 / 100 + 1 + shift, phi=1,
                                                               coupler_type='coupler', w=8, g=30, s=26),
                               elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 1 / 100 + shift + 1 / 6,
                                                               arc_finish=1 / 6 - 1 / 100 + shift, phi=0,
                                                               coupler_type='coupler', w=8, g=30, s=26),
                               elements.coaxmon.CoaxmonCoupler(arc_start=-5 / 6 + 1 / 100 + shift,
                                                               arc_finish=-3 / 6 - 1 / 100 + shift + 1 / 6,
                                                               phi=-1 / 2 - 1 / 3,
                                                               coupler_type=None, w=10, g=40)
                               ]

# Couplers_qubit_right_double_coupling = [elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift + 1 / 6,
#                                                                         arc_finish=-3 / 6 + 1 / 100 + shift + 1 / 6,
#                                                                         phi=-1 / 2,
#                                                                         coupler_type='grounded', w=10, s=6, g=20),
#                                         elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift,
#                                                                         arc_finish=3 / 6 - 1 / 100 + shift, phi=phi1,
#                                                                         coupler_type='coupler', w=10, g=10, s=6),
#                                         # for resonator
#                                         elements.coaxmon.CoaxmonCoupler(arc_start=3 / 6 + 2 / 100 + shift,
#                                                                         arc_finish=5 / 6 - 13 / 100 + shift, phi=1 / 2,
#                                                                         coupler_type='coupler', w=8, g=30, s=26),
#                                         # one upper
#                                         elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 11 / 100 + 1 + shift,
#                                                                         arc_finish=1 / 6 - 4 / 100 + 1 + shift, phi=1,
#                                                                         coupler_type='coupler', w=8, g=30, s=26),
#                                         elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 1 / 100 + shift + 1 / 6,
#                                                                         arc_finish=1 / 6 - 1 / 100 + shift, phi=0,
#                                                                         coupler_type='coupler', w=8, g=30, s=26),
#                                         elements.coaxmon.CoaxmonCoupler(arc_start=-5 / 6 + 1 / 100 + shift,
#                                                                         arc_finish=-3 / 6 - 1 / 100 + shift + 1 / 6,
#                                                                         phi=-1 / 2 - 1 / 3,
#                                                                         coupler_type=None, w=10, g=40)
#                                         ]
#
# Couplers_qubit_left = [
#     elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift, arc_finish=-3 / 6 + 1 / 100 + shift, phi=-1 / 2,
#                                     coupler_type=None, w=10, g=10),
#     elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift, arc_finish=3 / 6 - 1 / 100 + shift, phi=phi1,
#                                     coupler_type='coupler', w=10, g=10, s=6),  # for resonator
#     elements.coaxmon.CoaxmonCoupler(arc_start=3 / 6 + 2 / 100 + shift, arc_finish=5 / 6 - 13 / 100 + shift, phi=1 / 2,
#                                     coupler_type='coupler', w=8, g=30, s=26),  # one upper
#     elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 11 / 100 + shift, arc_finish=1 / 6 - 4 / 100 + shift, phi=0,
#                                     coupler_type='coupler', w=8, g=30, s=26),
#     elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 1 / 100 + 1 + shift, arc_finish=1 / 6 - 1 / 100 + 1 + shift,
#                                     phi=1,
#                                     coupler_type=None, w=10, g=10),
#     elements.coaxmon.CoaxmonCoupler(arc_start=-5 / 6 + 1 / 100 + shift, arc_finish=-3 / 6 - 1 / 100 + shift, phi=1,
#                                     coupler_type='grounded', w=10, s=6, g=20)]
#
# Couplers_qubit_left_double_coupling = [
#     elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift, arc_finish=-3 / 6 + 1 / 100 + shift, phi=-1 / 2,
#                                     coupler_type=None, w=10, g=10),
#     elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift, arc_finish=3 / 6 - 1 / 100 + shift, phi=phi1,
#                                     coupler_type='coupler', w=10, g=10, s=6),  # for resonator
#     elements.coaxmon.CoaxmonCoupler(arc_start=3 / 6 + 2 / 100 + shift, arc_finish=5 / 6 - 13 / 100 + shift, phi=1 / 2,
#                                     coupler_type='coupler', w=8, g=30, s=26),  # one upper
#     elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 11 / 100 + shift, arc_finish=1 / 6 - 4 / 100 + shift, phi=0,
#                                     coupler_type='coupler', w=8, g=30, s=26),
#     elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 1 / 100 + 1 + shift, arc_finish=1 / 6 - 1 / 100 + 1 + shift,
#                                     phi=1,
#                                     coupler_type='coupler', w=8, g=30, s=26),
#     elements.coaxmon.CoaxmonCoupler(arc_start=-5 / 6 + 1 / 100 + shift, arc_finish=-3 / 6 - 1 / 100 + shift, phi=1,
#                                     coupler_type='grounded', w=10, s=6, g=20)]

jj_coaxmon_sm_SQUID = {
    'a1': 30,
    'jj1_width': 0.5,
    'jj1_height': 0.5,
    'jj2_width': 0.15,
    'jj2_height': 0.5,
    'jj3_width': 0.15,
    'jj3_height': 0.15,
    'c2': 10,
    'angle_qubit': -np.pi / 2 - np.pi / 3,
    'angle_JJ': 0,
    'length': 10,
    'width': 5,
    'ic1': 0.5 * 0.5 * jc,
    'ic2': 0.15 * 0.15 * jc,
    'ic3': 0.15 * 0.15 * jc,
    'lm': 4.2e-12
}
jj_coaxmon_sm_SQUID1 = {
    'a1': 30,
    'jj1_width': 0.5,
    'jj1_height': 0.5,
    'jj2_width': 0.15,
    'jj2_height': 0.5,
    'jj3_width': 0.15,
    'jj3_height': 0.15,
    'c2': 10,
    'angle_qubit': -np.pi / 2 + np.pi / 3,
    'angle_JJ': 0,
    'length': 10,
    'width': 5,
    'ic1': 0.5 * 0.5 * jc,
    'ic2': 0.15 * 0.15 * jc,
    'ic3': 0.15 * 0.15 * jc,
    'lm': 4.2e-12
}
# Add coaxmon1
coaxmon1 = elements.coaxmon.Coaxmon(name='Coaxmon1',
                                    center=(
                                    sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length * 3 / 2,
                                    sample.chip_geometry.sample_vertical_size / 2 - qubit_position_offset),
                                    center_radius=100,
                                    inner_couplers_radius=140,
                                    outer_couplers_radius=200,
                                    inner_ground_radius=230,
                                    outer_ground_radius=250,
                                    layer_configuration=sample.layer_configuration,
                                    Couplers=Couplers_qubit_left_down, jj_params=jj_coaxmon_sm_SQUID,
                                    transformations={},
                                    calculate_capacitance=True, third_JJ=True)
# Add coaxmon2
coaxmon2 = elements.coaxmon.Coaxmon(name='Coaxmon2',
                                    center=(
                                    sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length / 2,
                                    sample.chip_geometry.sample_vertical_size / 2 - qubit_position_offset),
                                    center_radius=100,
                                    inner_couplers_radius=140,
                                    outer_couplers_radius=200,
                                    inner_ground_radius=230,
                                    outer_ground_radius=250,
                                    layer_configuration=sample.layer_configuration,
                                    Couplers=Couplers_qubit_left_down_double, jj_params=jj_coaxmon_sm_SQUID,
                                    transformations={},
                                    calculate_capacitance=True, third_JJ=True)
# Add coaxmon3
transformations3 = {'rotate': [np.pi, (sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length / 2,
                                      sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset)]}
coaxmon3 = elements.coaxmon.Coaxmon(name='Coaxmon3',
                                    center=(sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length / 2,
                                            sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset),
                                    center_radius=100,
                                    inner_couplers_radius=140,
                                    outer_couplers_radius=200,
                                    inner_ground_radius=230,
                                    outer_ground_radius=250,
                                    layer_configuration=sample.layer_configuration,
                                    Couplers=Couplers_qubit_right_double, jj_params=jj_coaxmon_sm_SQUID1,
                                    transformations=transformations3,
                                    calculate_capacitance=True, third_JJ=True)
# Add coaxmon4
transformations4 = {'rotate': [np.pi, (sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length * 3 / 2,
                                       sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset)]}

coaxmon4 = elements.coaxmon.Coaxmon(name='Coaxmon4',
                                    center=(
                                    sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length * 3 / 2,
                                    sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset),
                                    center_radius=100,
                                    inner_couplers_radius=140,
                                    outer_couplers_radius=200,
                                    inner_ground_radius=230,
                                    outer_ground_radius=250,
                                    layer_configuration=sample.layer_configuration,
                                    Couplers=Couplers_qubit_right, jj_params=jj_coaxmon_sm_SQUID1,
                                    transformations=transformations4,
                                    calculate_capacitance=True, third_JJ=True)
# # Add coaxmon5
# coaxmon5 = elements.coaxmon.Coaxmon(name='Coaxmon5',
#                                     center=(sample.chip_geometry.sample_horizontal_size / 2 + tunable_coupler_length / 2,
#                                             sample.chip_geometry.sample_vertical_size / 2 - qubit_position_offset),
#                                     center_radius=100,
#                                     inner_couplers_radius=140,
#                                     outer_couplers_radius=200,
#                                     inner_ground_radius=230,
#                                     outer_ground_radius=250,
#                                     layer_configuration=sample.layer_configuration,
#                                     Couplers=Couplers_qubit_left_down_double_coupling, jj_params=jj_coaxmon_sm_SQUID,
#                                     transformations={},
#                                     calculate_capacitance=True, third_JJ=True)
# # Add coaxmon6
# coaxmon6 = elements.coaxmon.Coaxmon(name='Coaxmon6',
#                                     center=(sample.chip_geometry.sample_horizontal_size / 2 + tunable_coupler_length * 3 / 2,
#                                             sample.chip_geometry.sample_vertical_size / 2 - qubit_position_offset),
#                                     center_radius=100,
#                                     inner_couplers_radius=140,
#                                     outer_couplers_radius=200,
#                                     inner_ground_radius=230,
#                                     outer_ground_radius=250,
#                                     layer_configuration=sample.layer_configuration,
#                                     Couplers=Couplers_qubit_right, jj_params=jj_coaxmon_sm_SQUID1, transformations={},
#                                     calculate_capacitance=True, third_JJ=True)
#
# # Add coaxmon7
# transformations7 = {'rotate': [np.pi, (sample.chip_geometry.sample_horizontal_size / 2 + tunable_coupler_length * 3 / 2,
#                                        sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset)]}
#
# coaxmon7 = elements.coaxmon.Coaxmon(name='Coaxmon7',
#                                     center=(sample.chip_geometry.sample_horizontal_size / 2 + tunable_coupler_length * 3 / 2,
#                                             sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset),
#                                     center_radius=100,
#                                     inner_couplers_radius=140,
#                                     outer_couplers_radius=200,
#                                     inner_ground_radius=230,
#                                     outer_ground_radius=250,
#                                     layer_configuration=sample.layer_configuration,
#                                     Couplers=Couplers_qubit_left, jj_params=jj_coaxmon_sm_SQUID,
#                                     transformations=transformations7,
#                                     calculate_capacitance=True, third_JJ=True)
#
# # Add coaxmon8
# transformations8 = {'rotate': [np.pi, (sample.chip_geometry.sample_horizontal_size / 2 + tunable_coupler_length / 2,
#                                        sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset)]}
#
# coaxmon8 = elements.coaxmon.Coaxmon(name='Coaxmon8',
#                                     center=(sample.chip_geometry.sample_horizontal_size / 2 + tunable_coupler_length / 2,
#                                             sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset),
#                                     center_radius=100,
#                                     inner_couplers_radius=140,
#                                     outer_couplers_radius=200,
#                                     inner_ground_radius=230,
#                                     outer_ground_radius=250,
#                                     layer_configuration=sample.layer_configuration,
#                                     Couplers=Couplers_qubit_right_double_coupling, jj_params=jj_coaxmon_sm_SQUID1,
#                                     transformations=transformations8,
#                                     calculate_capacitance=True, third_JJ=True)
#
#
#
#
#
#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4111/3390366865.py in <module>
#       1 Couplers_qubit_left_down = [
# ----> 2     elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift, arc_finish=-3 / 6 + 1 / 100 + shift, phi=-1 / 2,
#       3                                     coupler_type=None, w=10, g=10),
#       4     elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift, arc_finish=3 / 6 - 1 / 100 + shift,
#       5                                     phi=phi1 + 1 / 12,
#
# NameError: name 'elements' is not defined

# %%
Couplers_qubit_left_down = [
    elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift, arc_finish=-3 / 6 + 1 / 100 + shift, phi=-1 / 2,
                                    coupler_type=None, w=10, g=10),
    elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift, arc_finish=3 / 6 - 1 / 100 + shift,
                                    phi=phi1 + 1 / 12,
                                    coupler_type='coupler', w=10, g=10, s=6),  # for resonator
    elements.coaxmon.CoaxmonCoupler(arc_start=3 / 6 + 2 / 100 + shift, arc_finish=5 / 6 - 13 / 100 + shift, phi=1 / 2,
                                    coupler_type='coupler', w=8, g=30, s=26),  # one upper
    elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 11 / 100 + shift, arc_finish=1 / 6 - 4 / 100 + shift, phi=0,
                                    coupler_type='coupler', w=8, g=30, s=26),
    elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 1 / 100 + 1 + shift, arc_finish=1 / 6 - 1 / 100 + 1 + shift,
                                    phi=1,
                                    coupler_type=None, w=10, g=10),
    elements.coaxmon.CoaxmonCoupler(arc_start=-5 / 6 + 1 / 100 + shift, arc_finish=-3 / 6 - 1 / 100 + shift, phi=1,
                                    coupler_type='grounded', w=10, s=6, g=20)]

Couplers_qubit_right = [elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift + 1 / 6,
                                                        arc_finish=-3 / 6 + 1 / 100 + shift + 1 / 6, phi=-1 / 2,
                                                        coupler_type='grounded', w=10, s=6, g=20),
                        elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift,
                                                        arc_finish=3 / 6 - 1 / 100 + shift, phi=phi1,
                                                        coupler_type='coupler', w=10, g=10, s=6),  # for resonator
                        elements.coaxmon.CoaxmonCoupler(arc_start=3 / 6 + 2 / 100 + shift,
                                                        arc_finish=5 / 6 - 13 / 100 + shift, phi=1 / 2,
                                                        coupler_type='coupler', w=8, g=30, s=26),  # one upper
                        elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 11 / 100 + 1 + shift,
                                                        arc_finish=1 / 6 - 4 / 100 + 1 + shift, phi=1,
                                                        coupler_type='coupler', w=8, g=30, s=26),
                        elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 1 / 100 + shift + 1 / 6,
                                                        arc_finish=1 / 6 - 1 / 100 + shift, phi=0,
                                                        coupler_type=None, w=10, g=40),
                        elements.coaxmon.CoaxmonCoupler(arc_start=-5 / 6 + 1 / 100 + shift,
                                                        arc_finish=-3 / 6 - 1 / 100 + shift + 1 / 6, phi=-1 / 2 - 1 / 3,
                                                        coupler_type=None, w=10, g=40)
                        ]

Couplers_qubit_left_double=[elements.coaxmon.CoaxmonCoupler(arc_start=-1/6-1/100+shift,arc_finish=-3/6+1/100+shift,phi=-1/2,
                                          coupler_type= 'coupler', w=8, g=30, s=26),
                      elements.coaxmon.CoaxmonCoupler(arc_start=1/6+1/100+shift,arc_finish=3/6-1/100+shift,phi=phi1,
                                                      coupler_type='coupler', w=10, g=10, s=6),  # for resonator
                      elements.coaxmon.CoaxmonCoupler(arc_start=3/6+2/100+shift,arc_finish=5/6-13/100+shift,phi=1/2,
                                          coupler_type='coupler', w=8, g=30, s=26), #one upper
                      elements.coaxmon.CoaxmonCoupler(arc_start=-1/6+11/100+shift,arc_finish=1/6-4/100+shift,phi=0,
                                          coupler_type='coupler', w=8, g=30, s=26),
                      elements.coaxmon.CoaxmonCoupler(arc_start=-1/6+1 /100 + 1+shift,arc_finish=1/6-1/100+1+shift,phi=1,
                                                      coupler_type=None, w=10, g=10),
                      elements.coaxmon.CoaxmonCoupler(arc_start=-5/6+1/100+shift,arc_finish=-3/6-1/100+shift,phi=1,
                                          coupler_type='grounded',w =10,s=6, g=20)
]

Couplers_qubit_left_down_double = [elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 - 1 / 100 + shift + 1 / 6,
                                                                   arc_finish=-3 / 6 + 1 / 100 + shift + 1 / 6,
                                                                   phi=-1 / 2,
                                                                   coupler_type=None, w=10, g=40
                                                                   ),
                                   elements.coaxmon.CoaxmonCoupler(arc_start=1 / 6 + 1 / 100 + shift,
                                                                   arc_finish=3 / 6 - 1 / 100 + shift, phi=phi1,
                                                                   coupler_type='coupler', w=10, g=10, s=6),
                                   # for resonator
                                   elements.coaxmon.CoaxmonCoupler(arc_start=3 / 6 + 2 / 100 + shift,
                                                                   arc_finish=5 / 6 - 13 / 100 + shift, phi=1 / 2,
                                                                   coupler_type='coupler', w=8, g=30, s=26),
                                   # one upper
                                   elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 11 / 100 + 1 + shift,
                                                                   arc_finish=1 / 6 - 4 / 100 + 1 + shift, phi=1,
                                                                   coupler_type='coupler', w=8, g=30, s=26),
                                   elements.coaxmon.CoaxmonCoupler(arc_start=-1 / 6 + 1 / 100 + shift + 1 / 6,
                                                                   arc_finish=1 / 6 - 1 / 100 + shift, phi=0,
                                                                   coupler_type='coupler', w=8, g=30, s=26),
                                   elements.coaxmon.CoaxmonCoupler(arc_start=-5 / 6 + 1 / 100 + shift,
                                                                   arc_finish=-3 / 6 - 1 / 100 + shift + 1 / 6,
                                                                   phi=-1 / 2 - 1 / 3,
                                                                   coupler_type='grounded', w=10, s=6, g=20
                                                                   )
                                   ]

coaxmon1 = elements.coaxmon.Coaxmon(name='Coaxmon1',
                                    center=(
                                        sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length * 3 / 2,
                                        sample.chip_geometry.sample_vertical_size / 2 - qubit_position_offset),
                                    center_radius=100,
                                    inner_couplers_radius=140,
                                    outer_couplers_radius=200,
                                    inner_ground_radius=230,
                                    outer_ground_radius=250,
                                    layer_configuration=sample.layer_configuration,
                                    Couplers=Couplers_qubit_left_down, jj_params=jj_coaxmon_sm_SQUID,
                                    transformations={},
                                    calculate_capacitance=True, third_JJ=True)

coaxmon2 = elements.coaxmon.Coaxmon(name='Coaxmon2',
                                    center=(
                                    sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length / 2,
                                    sample.chip_geometry.sample_vertical_size / 2 - qubit_position_offset),
                                    center_radius=100,
                                    inner_couplers_radius=140,
                                    outer_couplers_radius=200,
                                    inner_ground_radius=230,
                                    outer_ground_radius=250,
                                    layer_configuration=sample.layer_configuration,
                                    Couplers=Couplers_qubit_left_down_double, jj_params=jj_coaxmon_sm_SQUID,
                                    transformations={},
                                    calculate_capacitance=True, third_JJ=True)

transformations3 = {'rotate': [np.pi, (sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length / 2,
                                       sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset)]}
coaxmon3 = elements.coaxmon.Coaxmon(name='Coaxmon3', center=(
sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length / 2,
sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset),
                                    center_radius=100,
                                    inner_couplers_radius=140,
                                    outer_couplers_radius=200,
                                    inner_ground_radius=230,
                                    outer_ground_radius=250,
                                    layer_configuration=sample.layer_configuration,
                                    Couplers=Couplers_qubit_left_double, jj_params=jj_coaxmon_sm_SQUID1,
                                    transformations=transformations3,
                                    calculate_capacitance=True, third_JJ=True)

transformations4 = {'rotate': [np.pi, (sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length * 3 / 2,
                                       sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset)]}

coaxmon4 = elements.coaxmon.Coaxmon(name='Coaxmon4',
                                    center=(
                                        sample.chip_geometry.sample_horizontal_size / 2 - tunable_coupler_length * 3 / 2,
                                        sample.chip_geometry.sample_vertical_size / 2 + qubit_position_offset),
                                    center_radius=100,
                                    inner_couplers_radius=140,
                                    outer_couplers_radius=200,
                                    inner_ground_radius=230,
                                    outer_ground_radius=250,
                                    layer_configuration=sample.layer_configuration,
                                    Couplers=Couplers_qubit_right, jj_params=jj_coaxmon_sm_SQUID1,
                                    transformations=transformations4,
                                    calculate_capacitance=True, third_JJ=True)
